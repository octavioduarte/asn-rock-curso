# %% [markdown]
# ### Origem da Probabilidade
#
# <br/>
#
# A origem da probabilidade se deu no século XV através da troca de cartas entre Blaise Pascal e Pierre de Fermat - O conteúdo dessas cartas envolvia pensar sobre chances de vencer em jogos de azar.
#
# Em uma dessas trocas de cartas fizeram uma reflexão onde cinco moedas seriam lançadas - Um escolheria cara e o outro coroa, depois do lançamento da terceira moeda teríamos:
#
# <br/>
#
#
# 🪙 Moeda 1 - Coroa
#
# 🪙 Moeda 2 - Coroa
#
# 🪙 Moeda 3 - Cara
#
# <br/>
#
# Supondo que por um motivo qualquer o jogo tivesse que ser interrompido neste momento - Como decidir quem seria o vencedor do jogo restando ainda duas moedas para serem lançadas?
#
# Nese caso podemos levantas as **possibilidades**:
#
# <hr/>
# Possibilidade 1:
# <br/>
# <br/>
#
# 🪙 Moeda 4 - Coroa
#
# 🪙 Moeda 5 - Coroa
#
# **Resultado**: 4 coroas 1 cara
#
# **Vence**: Quem escolheu coroa
# <hr/>
#
# Possibilidade 2:
# <br/>
# <br/>
#
# 🪙 Moeda 4 - Coroa
#
# 🪙 Moeda 5 - Cara
#
# **Resultado**: 3 coroas 2 caras
#
# **Vence**: Quem escolheu coroa
# <hr/>
#
# Possibilidade 3:
# <br/>
# <br/>
#
# 🪙 Moeda 4 - Cara
#
# 🪙 Moeda 5 - Coroa
#
# **Resultado**: 3 coroas 2 caras
#
# **Vence**: Quem escolheu coroa
# <hr/>
#
# Possibilidade 4:
# <br/>
# <br/>
#
# 🪙 Moeda 4 - Cara
#
# 🪙 Moeda 5 - Cara
#
# **Resultado**: 2 coroas 3 caras
#
# **Vence**: Quem escolheu cara
# <hr/>
# <br/>
#
#
# Neste caso podemos afirmar que é **provável** que o vencedor do jogo é quem escolheu coroa - Esta troca de cartas é o primeiro registro que temos sobre o uso da probabilidade.

# %% [markdown]
# ### Origem da <span><b style="color: blue">Esta</b></span>tística
#
# A estatística é uma palavra que tem sua origem associada ao <span><b style="color: blue">esta</b>do<span> - Onde os governos do século XVIII faziam levantamentos de dados sobre a sociedade para auxiliar na tomada de decisões.
#
# <br/>
#
# #### O termo "erro" na estatística:
#
# Estatística não procura fazer afirmações 100% assertiva - No Século XIX <a href="https://pt.wikipedia.org/wiki/Pierre-Simon_de_Laplace">Laplace</a> escreveu um livro sobre o cáculo de posições dos astros e nestes cáculos existia a função erro, contrapondo a ideia determinista da época.
